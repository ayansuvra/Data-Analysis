# %% [markdown]
# # Pandas

# %% [markdown]
# ### Pandas Series
# - 1D array holding data of any type. Pandas series is like a cloumn of a table.

# %%
import numpy as np
import pandas as pd

# %%
# using list
country = ['India', 'Nepal', 'Bhutan', 'USA', 'Russia']
countries = pd.Series(country)
countries
# Out:
# 0     India
# 1     Nepal
# 2    Bhutan
# 3       USA
# 4    Russia
# dtype: str

# %%
marks = [97, 94, 82, 77]
subjects = ['Eng', 'Math', 'Ben', 'Phy']

# custom indices
pd.Series(marks, index=subjects, name='My marks')
# Out:
# Eng     97
# Math    94
# Ben     82
# Phy     77
# Name: My marks, dtype: int64

# %%
# using dictionaries
marks = {
    'Math' : 94,
    'Phy' : 77,
    'Chem' : 71,
    'Bio' : 82
}
my_marks = pd.Series(marks, name='My marks')
my_marks
# Out:
# Math    94
# Phy     77
# Chem    71
# Bio     82
# Name: My marks, dtype: int64

# %%
# Attributes
my_marks.size
# Out:
# 4

# %%
my_marks.dtype
# Out:
# dtype('int64')

# %%
my_marks.name
# Out:
# 'My marks'

# %%
my_marks.is_unique
# Out:
# True

# %%
my_marks.index
# Out:
# Index(['Math', 'Phy', 'Chem', 'Bio'], dtype='str')

# %%
countries.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
my_marks.values
# Out:
# array([94, 77, 71, 82])

# %%
subs = pd.read_csv('./Datasets/subs.csv').squeeze()
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
vk_runs = pd.read_csv('./Datasets/kohli_ipl.csv',index_col='match_no').squeeze()
vk_runs
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('./Datasets/bollywood.csv',index_col='movie').squeeze()
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %%
movies.head(2)
# Out:
# movie
# Uri: The Surgical Strike    Vicky Kaushal
# Battalion 609                 Vicky Ahuja
# Name: lead, dtype: str

# %%
movies.tail(10)
# Out:
# movie
# Raaz (2002 film)                    Dino Morea
# Zameen (2003 film)                  Ajay Devgn
# Waisa Bhi Hota Hai Part II        Arshad Warsi
# Devdas (2002 Hindi film)        Shah Rukh Khan
# Kaante                        Amitabh Bachchan
# Hum Tumhare Hain Sanam          Shah Rukh Khan
# Aankhen (2002 film)           Amitabh Bachchan
# Saathiya (film)                   Vivek Oberoi
# Company (film)                      Ajay Devgn
# Awara Paagal Deewana              Akshay Kumar
# Name: lead, dtype: str

# %%
movies.sample(6)
# Out:
# movie
# Lucky Kabootar              Arvinder Bhatti
# Jurm (2005 film)                 Kamal Adib
# Kuchh Bheege Alfaaz        Geetanjali Thapa
# Sonchiriya             Sushant Singh Rajput
# Tamanchey                    Nikhil Dwivedi
# Gold (2018 film)               Akshay Kumar
# Name: lead, dtype: str

# %%
movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Tanishaa Mukerji     1
# Tanuja               1
# Ankit                1
# Rakhee Gulzar        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
vk_runs.sort_values(ascending=False)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
#       ...
# 93       0
# 130      0
# 206      0
# 207      0
# 211      0
# Name: runs, Length: 215, dtype: int64

# %%
# highest score
vk_runs.sort_values(ascending=False).head(1).values[0]
# Out:
# np.int64(113)

# %%
vk_runs.sort_values(inplace=True)

# %%
vk_runs
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
movies.sort_index(inplace=True)

# %%
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: str

# %%
# math methods
vk_runs.count()
# Out:
# np.int64(215)

# %%
vk_runs.size
# Out:
# 215

# %%
vk_runs.sum()
# Out:
# np.int64(6634)

# %%
vk_runs.product()
# Out:
# np.int64(0)

# %%
vk_runs.mean()
# Out:
# np.float64(30.855813953488372)

# %%
vk_runs.median()
# Out:
# np.float64(24.0)

# %%
movies.mode()
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: str

# %%
vk_runs.std()
# Out:
# np.float64(26.22980132830278)

# %%
vk_runs.var()
# Out:
# np.float64(688.0024777222343)

# %%
subs.max()
# Out:
# np.int64(396)

# %%
subs.min()
# Out:
# np.int64(33)

# %%
vk_runs.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
# indexing and slicing
vk_runs
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
vk_runs[8]
# Out:
# np.int64(0)

# %%
# negetive indexing is not applicable for pd series

# %%
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: str

# %%
movies['Zindagi 50-50']
# Out:
# 'Veena Malik'

# %%
vk_runs[8:11]
# Out:
# match_no
# 211    0
# 106    1
# 204    1
# Name: runs, dtype: int64

# %%
movies[8:11]
# Out:
# movie
# 3 Idiots                  Aamir Khan
# 3 Storeys                Aisha Ahmed
# 31st October (film)    Soha Ali Khan
# Name: lead, dtype: str

# %%
countries[1:4]
# Out:
# 1     Nepal
# 2    Bhutan
# 3       USA
# dtype: str

# %%
t = pd.Series([2, 4, 78, 2, 1], index=['a', 'b', 'c', 'd', 'e'])
t
# Out:
# a     2
# b     4
# c    78
# d     2
# e     1
# dtype: int64

# %%
t[1:3]
# Out:
# b     4
# c    78
# dtype: int64

# %%
t['b':'d']
# Out:
# b     4
# c    78
# d     2
# dtype: int64

# %%
# fancy indexing
vk_runs[[1, 3, 8]]
# Out:
# match_no
# 1     1
# 3    13
# 8     0
# Name: runs, dtype: int64

# %%
'Zindagi Na Milegi Dobara' in movies
# Out:
# True

# %%
'Arjun Kapoor' in movies.values
# Out:
# True

# %%
dict(marks)
# Out:
# {'Math': 94, 'Phy': 77, 'Chem': 71, 'Bio': 82}

# %%
marks = pd.Series(marks)
for i in marks.index:
    print(i)
# Out:
# Math
# Phy
# Chem
# Bio

# %%
5 + marks
# Out:
# Math    99
# Phy     82
# Chem    76
# Bio     87
# dtype: int64

# %%
90 > marks
# Out:
# Math    False
# Phy      True
# Chem     True
# Bio      True
# dtype: bool

# %%
marks[marks > 90] # boolean indexing
# Out:
# Math    94
# dtype: int64

# %%
# number of ducks
vk_runs[vk_runs == 0].count()
# Out:
# np.int64(9)

# %%
# actors with more than 20 movies
movies.value_counts()[movies.value_counts()>20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
# plotting
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(10).plot(kind='pie')
# Out:
# <Axes: >

# %%
# astype
vk_runs.info()
# Out:
# <class 'pandas.Series'>
# Index: 215 entries, 8 to 128
# Series name: runs
# Non-Null Count  Dtype
# --------------  -----
# 215 non-null    int64
# dtypes: int64(1)
# memory usage: 11.5 KB

# %%
vk_runs.astype('int16').info()
# Out:
# <class 'pandas.Series'>
# Index: 215 entries, 8 to 128
# Series name: runs
# Non-Null Count  Dtype
# --------------  -----
# 215 non-null    int16
# dtypes: int16(1)
# memory usage: 10.2 KB

# %%
# between
vk_runs[vk_runs.between(10, 80)].size
# Out:
# 149

# %%
vk_runs.clip(40, 100)
# Out:
# match_no
# 8       40
# 87      40
# 93      40
# 91      40
# 206     40
#       ...
# 164    100
# 120    100
# 123    100
# 126    100
# 128    100
# Name: runs, Length: 215, dtype: int64

# %%
temp = pd.Series([1, 1, 2, 9, 9, 2, 2, 7, 4, 8])
temp.drop_duplicates()
# Out:
# 0    1
# 2    2
# 3    9
# 7    7
# 8    4
# 9    8
# dtype: int64

# %%
# by default it is taking first value, but it can be changed using keep parameter
temp.drop_duplicates(keep='last')
# Out:
# 1    1
# 4    9
# 6    2
# 7    7
# 8    4
# 9    8
# dtype: int64

# %%
temp.duplicated().sum()
# Out:
# np.int64(4)

# %%
# is nun
temp = pd.Series([2, 1, np.nan, 0, np.nan, 0, np.nan, 88, 9])
temp
# Out:
# 0     2.0
# 1     1.0
# 2     NaN
# 3     0.0
# 4     NaN
# 5     0.0
# 6     NaN
# 7    88.0
# 8     9.0
# dtype: float64

# %%
temp.isnull().sum()
# Out:
# np.int64(3)

# %%
temp.size # returns number of elements
# Out:
# 9

# %%
temp.count() # count values except null values
# Out:
# np.int64(6)

# %%
# dropna -> removes all missing values
temp.dropna()
# Out:
# 0     2.0
# 1     1.0
# 3     0.0
# 5     0.0
# 7    88.0
# 8     9.0
# dtype: float64

# %%
# fillna -> fill missing value
temp.fillna(np.round(temp.mean(),2))
# Out:
# 0     2.00
# 1     1.00
# 2    16.67
# 3     0.00
# 4    16.67
# 5     0.00
# 6    16.67
# 7    88.00
# 8     9.00
# dtype: float64

# %%
# isin
vk_runs[vk_runs.isin([11, 0 , 8, 100])]
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
# 207      0
# 135      0
# 130      0
# 211      0
# 163      8
# 189      8
# 150      8
# 183      8
# 53       8
# 55       8
# 14      11
# 50      11
# 76      11
# 164    100
# 120    100
# Name: runs, dtype: int64

# %%
movies.apply(lambda x:x.split()[0]) # apply custome function to series
# Out:
# movie
# 1920 (film)                 Rajniesh
# 1920: London                 Sharman
# 1920: The Evil Returns         Vicky
# 1971 (2007 film)               Manoj
# 2 States (2014 film)           Arjun
#                               ...
# Zindagi 50-50                  Veena
# Zindagi Na Milegi Dobara     Hrithik
# Zindagi Tere Naam             Mithun
# Zokkomon                    Darsheel
# Zor Lagaa Ke...Haiya!         Meghan
# Name: lead, Length: 1500, dtype: str

# %%
subs.apply(lambda x : 'good day' if x > 134 else 'bad day')
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: str

# %%
# copy 
new = vk_runs.head().copy()
new
# Out:
# match_no
# 8      0
# 87     0
# 93     0
# 91     0
# 206    0
# Name: runs, dtype: int64

# %% [markdown]
# ## Pandas DataFrame

# %%
# using list
students = [
    [100, 9, 12],
    [90, 8.5, 10],
    [80, 6.6, 5]
]
pd.DataFrame(students, columns=['iq', 'gpa', 'package'], index=['alex', 'anna', 'ayan'])
# Out:
#        iq  gpa  package
# alex  100  9.0       12
# anna   90  8.5       10
# ayan   80  6.6        5

# %%
# using dict 
students = {
    'iq' : [100, 9, 12],
    'gpa' : [9, 8.5, 10],
    'package' : [80, 6.6, 5]
}
pd.DataFrame(students)
# Out:
#     iq   gpa  package
# 0  100   9.0     80.0
# 1    9   8.5      6.6
# 2   12  10.0      5.0

# %%
movies = pd.read_csv('Datasets/movies.csv')
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
ipl = pd.read_csv('Datasets/ipl-matches.csv')
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
print(movies.shape, ipl.shape)
# Out:
# (1629, 18) (950, 20)

# %%
movies.dtypes
# Out:
# title_x                 str
# imdb_id                 str
# poster_path             str
# wiki_link               str
# title_y                 str
# original_title          str
# is_adult              int64
# year_of_release       int64
# runtime                 str
# genres                  str
# imdb_rating         float64
# imdb_votes            int64
# story                   str
# summary                 str
# tagline                 str
# actors                  str
# wins_nominations        str
# release_date            str
# dtype: object

# %%
ipl.dtypes
# Out:
# ID                   int64
# City                   str
# Date                   str
# Season                 str
# MatchNumber            str
# Team1                  str
# Team2                  str
# Venue                  str
# TossWinner             str
# TossDecision           str
# SuperOver              str
# WinningTeam            str
# WonBy                  str
# Margin             float64
# method                 str
# Player_of_Match        str
# Team1Players           str
# Team2Players           str
# Umpire1                str
# Umpire2                str
# dtype: object

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='str')

# %%
students.values()
# Out:
# dict_values([[100, 9, 12], [9, 8.5, 10], [80, 6.6, 5]])

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   str
#  1   imdb_id           1629 non-null   str
#  2   poster_path       1526 non-null   str
#  3   wiki_link         1629 non-null   str
#  4   title_y           1629 non-null   str
#  5   original_title    1629 non-null   str
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   str
#  9   genres            1629 non-null   str
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   str
#  13  summary           1629 non-null   str
#  14  tagline           557 non-null    str
#  15  actors            1624 non-null   str
#  16  wins_nominations  707 non-null    str
# ...

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
movies.duplicated().value_counts()
# Out:
# False    1629
# Name: count, dtype: int64

# %%
ipl.duplicated().value_counts()
# Out:
# False    950
# Name: count, dtype: int64

# %%
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
students_df = pd.DataFrame(students)
students_df
# Out:
#     iq   gpa  package
# 0  100   9.0     80.0
# 1    9   8.5      6.6
# 2   12  10.0      5.0

# %%
students_df.rename(columns={'gpa' : 'marks', 'package' : 'LPA'}, inplace=True)

# %%
students_df
# Out:
#     iq  marks   LPA
# 0  100    9.0  80.0
# 1    9    8.5   6.6
# 2   12   10.0   5.0

# %%
students_df.sum()
# Out:
# iq       121.0
# marks     27.5
# LPA       91.6
# dtype: float64

# %%
students_df.sum(axis=1)
# Out:
# 0    189.0
# 1     24.1
# 2     27.0
# dtype: float64

# %%
students_df.max() # min, std, var, mean
# Out:
# iq       100.0
# marks     10.0
# LPA       80.0
# dtype: float64

# %%
movies['genres']
# Out:
# 0       Action|Drama|War
# 1                    War
# 2        Biography|Drama
# 3            Crime|Drama
# 4                  Drama
#               ...
# 1624               Drama
# 1625               Drama
# 1626        Comedy|Drama
# 1627              Action
# 1628       Drama|Romance
# Name: genres, Length: 1629, dtype: str

# %%
movies.iloc[0] # fancy, slicing works on iloc
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
# movie names using iloc
movies.iloc[0:10]['original_title']
# Out:
# 0            Uri: The Surgical Strike
# 1                       Battalion 609
# 2       The Accidental Prime Minister
# 3                     Why Cheat India
# 4                     Evening Shadows
# 5                                Soni
# 6                       Fraud Saiyyan
# 7                          Bombairiya
# 8    Manikarnika: The Queen of Jhansi
# 9                           Thackeray
# Name: original_title, dtype: str

# %%
movies['original_title'].head(10)
# Out:
# 0            Uri: The Surgical Strike
# 1                       Battalion 609
# 2       The Accidental Prime Minister
# 3                     Why Cheat India
# 4                     Evening Shadows
# 5                                Soni
# 6                       Fraud Saiyyan
# 7                          Bombairiya
# 8    Manikarnika: The Queen of Jhansi
# 9                           Thackeray
# Name: original_title, dtype: str

# %%
students
# Out:
# {'iq': [100, 9, 12], 'gpa': [9, 8.5, 10], 'package': [80, 6.6, 5]}

# %%
students = [
    [100, 9, 12],
    [90, 8.5, 10],
    [80, 6.6, 5]
]
students = pd.DataFrame(students, columns=['iq', 'gpa', 'package'], index=['alex', 'anna', 'ayan'])
students
# Out:
#        iq  gpa  package
# alex  100  9.0       12
# anna   90  8.5       10
# ayan   80  6.6        5

# %%
students.loc['alex' : 'ayan']
# Out:
#        iq  gpa  package
# alex  100  9.0       12
# anna   90  8.5       10
# ayan   80  6.6        5

# %%
# loc -> uses label to fetch rows
# iloc -> uses indices to fetch rows
students.iloc[0]
# Out:
# iq         100.0
# gpa          9.0
# package     12.0
# Name: alex, dtype: float64

# %%
movies.iloc[0:3, 0:4]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
# winners
ipl[ipl['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# superover
ipl[ipl['SuperOver'] == 'Y'][['Season', 'Team1', 'Team2']]
# Out:
#       Season                        Team1                        Team2
# 114     2021               Delhi Capitals          Sunrisers Hyderabad
# 158  2020/21        Kolkata Knight Riders          Sunrisers Hyderabad
# 159  2020/21               Mumbai Indians              Kings XI Punjab
# 184  2020/21  Royal Challengers Bangalore               Mumbai Indians
# 192  2020/21               Delhi Capitals              Kings XI Punjab
# 203     2019               Mumbai Indians          Sunrisers Hyderabad
# 244     2019        Kolkata Knight Riders               Delhi Capitals
# 339     2017                Gujarat Lions               Mumbai Indians
# 474     2015             Rajasthan Royals              Kings XI Punjab
# 533     2014        Kolkata Knight Riders             Rajasthan Royals
# 608     2013  Royal Challengers Bangalore             Delhi Daredevils
# 621     2013          Sunrisers Hyderabad  Royal Challengers Bangalore
# ...

# %%
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
# matches won by csk in kolkata
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] =='Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
# Toss winner is match winner
ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0] * 100
# Out:
# 51.473684210526315

# %%
# movies with rating > 8 and voting > 10,000
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)]['original_title']
# Out:
# 0                Uri: The Surgical Strike
# 11                              Gully Boy
# 37                             Article 15
# 40                               Super 30
# 143                               Tumbbad
# 146                             Andhadhun
# 325                                  Pink
# 354                                Dangal
# 418                                Masaan
# 426                              Drishyam
# 436                                Talvar
# 469                                 Queen
# 536                                Haider
# 566                                  Ugly
# 567                                    PK
# 589                          Vishwaroopam
# 612                    Bhaag Milkha Bhaag
# 638                                Shahid
# 668                      Paan Singh Tomar
# 669                               Kahaani
# 693                    Gangs of Wasseypur
# 694                    Gangs of Wasseypur
# ...

# %%
# action movies with > 7.5 rating
movies[(movies['genres'].str.split('|').apply(lambda x : 'Action' in x)) & (movies['imdb_rating'] > 7.5)]['original_title']
# Out:
# 0            Uri: The Surgical Strike
# 41               Family of Thakurganj
# 84                          Mukkabaaz
# 106                             Raazi
# 110     Parmanu: The Story of Pokhran
# 112           Bhavesh Joshi Superhero
# 169                  The Ghazi Attack
# 219                         Raag Desh
# 258                     Saala Khadoos
# 280                         Laal Rang
# 297                       Udta Punjab
# 354                            Dangal
# 362                 Bajrangi Bhaijaan
# 365                              Baby
# 393        Detective Byomkesh Bakshy!
# 449                             Titli
# 536                            Haider
# 589                      Vishwaroopam
# 625                       Madras Cafe
# 668                  Paan Singh Tomar
# 693                Gangs of Wasseypur
# 694                Gangs of Wasseypur
# 982                      Jodhaa Akbar
# 1039                             1971
# 1058                     Black Friday
# ...

# %%
# new column -> lead actor
movies.dropna(inplace=True)
movies['lead_actor'] = movies['actors'].str.split('|').apply(lambda x : x[0])

# %%
movies
# Out:
#                       title_x     imdb_id  \
# 11                  Gully Boy   tt2395469
# 34              Yeh Hai India   tt5525846
# 37          Article 15 (film)  tt10324144
# 87                    Aiyaary   tt6774212
# 96           Raid (2018 film)   tt7363076
# ...                       ...         ...
# 1600                   Kasoor   tt0272688
# 1601         Maya (2001 film)   tt0299027
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1621                  Tum Bin   tt0290326
# 1623                 Zubeidaa   tt0255713
#
#                                             poster_path  \
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# Toss decision plot
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: >

# %%
# total matches played by each team
runs_of_teams = (ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)

# %%
movies.head()
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
# 87            Aiyaary   tt6774212
# 96   Raid (2018 film)   tt7363076
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
# 87  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
# 87            https://en.wikipedia.org/wiki/Aiyaary        Aiyaary
# 96   https://en.wikipedia.org/wiki/Raid_(2018_film)           Raid
#
# ...

# %%
movies.sort_values('title_x')
# Out:
#                   title_x    imdb_id  \
# 1039     1971 (2007 film)  tt0983990
# 912              3 Idiots  tt1187043
# 1135        36 China Town  tt0477252
# 1055             68 Pages  tt1151299
# 886   Aakrosh (2010 film)  tt1708453
# ...                   ...        ...
# 1035             Yuvvraaj  tt1105747
# 1312                Zeher  tt0451983
# 560       Zid (2014 film)  tt4228746
# 1224         Zinda (film)  tt0488906
# 1623             Zubeidaa  tt0255713
#
#                                             poster_path  \
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# 912   https://upload.wikimedia.org/wikipedia/en/thum...
# 1135  https://upload.wikimedia.org/wikipedia/en/thum...
# 1055  https://upload.wikimedia.org/wikipedia/en/thum...
# 886   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1035  https://upload.wikimedia.org/wikipedia/en/thum...
# 1312  https://upload.wikimedia.org/wikipedia/en/c/ce...
# ...

# %%
# based on multiple columns
movies.sort_values(['year_of_release', 'title_x'], ascending=[True, False])
# Out:
#                       title_x     imdb_id  \
# 1623                 Zubeidaa   tt0255713
# 1573      Yaadein (2001 film)   tt0248617
# 1621                  Tum Bin   tt0290326
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1601         Maya (2001 film)   tt0299027
# ...                       ...         ...
# 112   Bhavesh Joshi Superhero   tt6129302
# 99                   Baaghi 2   tt6843812
# 87                    Aiyaary   tt6774212
# 11                  Gully Boy   tt2395469
# 37          Article 15 (film)  tt10324144
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1573  https://upload.wikimedia.org/wikipedia/en/thum...
# 1621  https://upload.wikimedia.org/wikipedia/en/thum...
# 1607  https://upload.wikimedia.org/wikipedia/en/thum...
# 1601  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 112   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
runs_of_teams = pd.DataFrame(runs_of_teams)
runs_of_teams.reset_index()
# Out:
#                           Team1  count
# 0                Mumbai Indians    231
# 1   Royal Challengers Bangalore    226
# 2         Kolkata Knight Riders    223
# 3           Chennai Super Kings    208
# 4              Rajasthan Royals    192
# 5               Kings XI Punjab    190
# 6              Delhi Daredevils    161
# 7           Sunrisers Hyderabad    152
# 8               Deccan Chargers     75
# 9                Delhi Capitals     63
# 10                Pune Warriors     46
# 11                Gujarat Lions     30
# 12                 Punjab Kings     28
# 13               Gujarat Titans     16
# 14       Rising Pune Supergiant     16
# 15         Lucknow Super Giants     15
# 16         Kochi Tuskers Kerala     14
# 17      Rising Pune Supergiants     14

# %%
runs_of_teams['rank'] = runs_of_teams['count'].rank(ascending=False)
runs_of_teams
# Out:
#                              count  rank
# Team1
# Mumbai Indians                 231   1.0
# Royal Challengers Bangalore    226   2.0
# Kolkata Knight Riders          223   3.0
# Chennai Super Kings            208   4.0
# Rajasthan Royals               192   5.0
# Kings XI Punjab                190   6.0
# Delhi Daredevils               161   7.0
# Sunrisers Hyderabad            152   8.0
# Deccan Chargers                 75   9.0
# Delhi Capitals                  63  10.0
# Pune Warriors                   46  11.0
# Gujarat Lions                   30  12.0
# Punjab Kings                    28  13.0
# Gujarat Titans                  16  14.5
# Rising Pune Supergiant          16  14.5
# Lucknow Super Giants            15  16.0
# Kochi Tuskers Kerala            14  17.5
# Rising Pune Supergiants         14  17.5

# %%
runs_of_teams.sort_index()
# Out:
#                              count  rank
# Team1
# Chennai Super Kings            208   4.0
# Deccan Chargers                 75   9.0
# Delhi Capitals                  63  10.0
# Delhi Daredevils               161   7.0
# Gujarat Lions                   30  12.0
# Gujarat Titans                  16  14.5
# Kings XI Punjab                190   6.0
# Kochi Tuskers Kerala            14  17.5
# Kolkata Knight Riders          223   3.0
# Lucknow Super Giants            15  16.0
# Mumbai Indians                 231   1.0
# Pune Warriors                   46  11.0
# Punjab Kings                    28  13.0
# Rajasthan Royals               192   5.0
# Rising Pune Supergiant          16  14.5
# Rising Pune Supergiants         14  17.5
# Royal Challengers Bangalore    226   2.0
# Sunrisers Hyderabad            152   8.0

# %%
runs_of_teams.set_index('rank')
# Out:
#       count
# rank
# 1.0     231
# 2.0     226
# 3.0     223
# 4.0     208
# 5.0     192
# 6.0     190
# 7.0     161
# 8.0     152
# 9.0      75
# 10.0     63
# 11.0     46
# 12.0     30
# 13.0     28
# 14.5     16
# 14.5     16
# 16.0     15
# 17.5     14
# 17.5     14

# %%
runs_of_teams.reset_index().set_index('rank')
# Out:
#                             Team1  count
# rank
# 1.0                Mumbai Indians    231
# 2.0   Royal Challengers Bangalore    226
# 3.0         Kolkata Knight Riders    223
# 4.0           Chennai Super Kings    208
# 5.0              Rajasthan Royals    192
# 6.0               Kings XI Punjab    190
# 7.0              Delhi Daredevils    161
# 8.0           Sunrisers Hyderabad    152
# 9.0               Deccan Chargers     75
# 10.0               Delhi Capitals     63
# 11.0                Pune Warriors     46
# 12.0                Gujarat Lions     30
# 13.0                 Punjab Kings     28
# 14.5               Gujarat Titans     16
# 14.5       Rising Pune Supergiant     16
# 16.0         Lucknow Super Giants     15
# 17.5         Kochi Tuskers Kerala     14
# 17.5      Rising Pune Supergiants     14

# %%
runs_of_teams.rename(index={'Mumbai Indians' : 'MI'})
# Out:
#                              count  rank
# Team1
# MI                             231   1.0
# Royal Challengers Bangalore    226   2.0
# Kolkata Knight Riders          223   3.0
# Chennai Super Kings            208   4.0
# Rajasthan Royals               192   5.0
# Kings XI Punjab                190   6.0
# Delhi Daredevils               161   7.0
# Sunrisers Hyderabad            152   8.0
# Deccan Chargers                 75   9.0
# Delhi Capitals                  63  10.0
# Pune Warriors                   46  11.0
# Gujarat Lions                   30  12.0
# Punjab Kings                    28  13.0
# Gujarat Titans                  16  14.5
# Rising Pune Supergiant          16  14.5
# Lucknow Super Giants            15  16.0
# Kochi Tuskers Kerala            14  17.5
# Rising Pune Supergiants         14  17.5

# %%
runs_of_teams.nunique() # doesn't count missing values
# Out:
# count    16
# rank     16
# dtype: int64

# %%
# has nans -> any missing value exist
runs_of_teams['rank'].hasnans
# Out:
# False

# %%
students = [
    [100, 9, 12],
    [90, 8.5, 10],
    [80, 6.6, 5],
    [np.nan, np.nan, np.nan],
    [110, 9.2, np.nan]
]
students = pd.DataFrame(students, columns=['iq', 'gpa', 'package'])

# %%
students.dropna(how='all') # how = 'any'
# Out:
#       iq  gpa  package
# 0  100.0  9.0     12.0
# 1   90.0  8.5     10.0
# 2   80.0  6.6      5.0
# 4  110.0  9.2      NaN

# %%
students.dropna(subset=['package']) # remove rows where package is null
# Out:
#       iq  gpa  package
# 0  100.0  9.0     12.0
# 1   90.0  8.5     10.0
# 2   80.0  6.6      5.0

# %%
students.fillna('-')
# Out:
#       iq  gpa package
# 0  100.0  9.0    12.0
# 1   90.0  8.5    10.0
# 2   80.0  6.6     5.0
# 3      -    -       -
# 4  110.0  9.2       -

# %%
# find the last match played by virat kohli in Delhi
ipl['TotalPlayers'] = ipl['Team1Players'] + ipl['Team2Players']
vk_played = ipl[ipl['TotalPlayers'].apply(lambda x : 'V Kohli' in x)]

# %%
vk_played[vk_played['City'] == 'Delhi'].sort_values('Date', ascending=False).head(1)
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ...     WinningTeam WonBy Margin  method Player_of_Match  \
# 208          bat  ...  Delhi Capitals  Runs   16.0     NaN        S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                       TotalPlayers
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
# [1 rows x 21 columns]

# %%
students
# Out:
#       iq  gpa  package
# 0  100.0  9.0     12.0
# 1   90.0  8.5     10.0
# 2   80.0  6.6      5.0
# 3    NaN  NaN      NaN
# 4  110.0  9.2      NaN

# %%
students.drop(index=[0, 1])
# Out:
#       iq  gpa  package
# 2   80.0  6.6      5.0
# 3    NaN  NaN      NaN
# 4  110.0  9.2      NaN

# %%
students.drop(columns=['gpa'])
# Out:
#       iq  package
# 0  100.0     12.0
# 1   90.0     10.0
# 2   80.0      5.0
# 3    NaN      NaN
# 4  110.0      NaN

# %%
points = {
    '1st Point' : [(3, 9), (0, 1), (3, 7), (5, 5)],
    '2nd Point' : [(4, -1), (1, -2), (5, -7), (0, -2)]
}
points = pd.DataFrame(points)
points
# Out:
#   1st Point 2nd Point
# 0    (3, 9)   (4, -1)
# 1    (0, 1)   (1, -2)
# 2    (3, 7)   (5, -7)
# 3    (5, 5)   (0, -2)

# %%
# apply function on df
def distance(points):
    point_A = points['1st Point']
    point_B = points['2nd Point']
    return round(((point_A[0]-point_B[0])**2 + (point_A[1]-point_B[1])**2)**0.5, 2)

points.apply(distance, axis=1)
# Out:
# 0    10.05
# 1     3.16
# 2    14.14
# 3     8.60
# dtype: float64

# %% [markdown]
# ## Pandas GroupBy

# %%
imdb_movies = pd.read_csv('./Datasets/imdb-top-1000.csv')
ipl = pd.read_csv('./Datasets/ipl-matches.csv')

# %%
imdb_movies.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
imdb_movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   str
#  1   Released_Year  1000 non-null   str
#  2   Runtime        1000 non-null   int64
#  3   Genre          1000 non-null   str
#  4   IMDB_Rating    1000 non-null   float64
#  5   Director       1000 non-null   str
#  6   Star1          1000 non-null   str
#  7   No_of_Votes    1000 non-null   int64
#  8   Gross          1000 non-null   float64
#  9   Metascore      843 non-null    float64
# dtypes: float64(3), int64(2), str(5)
# memory usage: 78.3 KB

# %%
# groupby is applied to categorical column
# based on genres
genres = imdb_movies.groupby('Genre')
genres

# %%
genres['IMDB_Rating'].mean()
# Out:
# Genre
# Action       7.949419
# Adventure    7.937500
# Animation    7.930488
# Biography    7.938636
# Comedy       7.901290
# Crime        8.016822
# Drama        7.957439
# Family       7.800000
# Fantasy      8.000000
# Film-Noir    7.966667
# Horror       7.909091
# Mystery      7.975000
# Thriller     7.800000
# Western      8.350000
# Name: IMDB_Rating, dtype: float64

# %%
# top 3 genres by total earning
genres['Gross'].sum().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
top3_revenue = imdb_movies.groupby('Genre')['Gross']
top3_revenue.sum().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
# Find the director with most votes
imdb_movies.groupby('Director')['No_of_Votes'].sum().sort_values(ascending=False).head(1)
# Out:
# Director
# Christopher Nolan    11578345
# Name: No_of_Votes, dtype: int64

# %%
# find the highest rated movie of each genre
imdb_movies.groupby('Genre')[['Series_Title', 'IMDB_Rating']].max()
# Out:
#                                   Series_Title  IMDB_Rating
# Genre
# Action                                 Yôjinbô          9.0
# Adventure                           Zombieland          8.6
# Animation          Ôkami kodomo no Ame to Yuki          8.6
# Biography                              Zerkalo          8.9
# Comedy                Zindagi Na Milegi Dobara          8.6
# Crime                        À bout de souffle          9.2
# Drama                                Zwartboek          9.3
# Family     Willy Wonka & the Chocolate Factory          7.8
# Fantasy                              Nosferatu          8.1
# Film-Noir                        The Third Man          8.1
# Horror                               The Thing          8.5
# Mystery                                Vertigo          8.4
# Thriller                       Wait Until Dark          7.8
# Western                 The Outlaw Josey Wales          8.8

# %%
len(genres) # no.of groups
# Out:
# 14

# %%
genres.size() # no. of rows on each group
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
# genres.first() -> 1st row of each group
# genres.last() -> last row of each group
# genres.nth(x) -> nth row of each group(0-index based)

# %%
# all rows of a group
genres.get_group('Family')
# Out:
#                             Series_Title Released_Year  Runtime   Genre  \
# 688           E.T. the Extra-Terrestrial          1982      115  Family
# 698  Willy Wonka & the Chocolate Factory          1971      100  Family
#
#      IMDB_Rating          Director         Star1  No_of_Votes        Gross  \
# 688          7.8  Steven Spielberg  Henry Thomas       372490  435110554.0
# 698          7.8        Mel Stuart   Gene Wilder       178731    4000000.0
#
#      Metascore
# 688       91.0
# 698       67.0

# %%
genres.groups # index position of rows
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
genres.describe()
# Out:
#           Runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# Genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# ...

# %%
# genres.head() -> first n rows of each group
# genres.tail() -> last n rows of each group
# genres.sample() -> random row form each group

# %%
genres.sum()
temp = imdb_movies.groupby('Genre')[['Runtime', 'IMDB_Rating', 'No_of_Votes','Metascore']]
temp.agg(['min', 'max', 'mean'])
# Out:
#           Runtime                  IMDB_Rating                No_of_Votes  \
#               min  max        mean         min  max      mean         min
# Genre
# Action         45  321  129.046512         7.6  9.0  7.949419       25312
# Adventure      88  228  134.111111         7.6  8.6  7.937500       29999
# Animation      71  137   99.585366         7.6  8.6  7.930488       25229
# Biography      93  209  136.022727         7.6  8.9  7.938636       27254
# Comedy         68  188  112.129032         7.6  8.6  7.901290       26337
# Crime          80  229  126.392523         7.6  9.2  8.016822       27712
# Drama          64  242  124.737024         7.6  9.3  7.957439       25088
# Family        100  115  107.500000         7.8  7.8  7.800000      178731
# Fantasy        76   94   85.000000         7.9  8.1  8.000000       57428
# Film-Noir     100  108  104.000000         7.8  8.1  7.966667       59556
# Horror         71  122  102.090909         7.6  8.5  7.909091       27007
# ...

# %%
temp.agg({
    'IMDB_Rating' : 'mean',
    'No_of_Votes' : 'sum',
    'Metascore' : 'min',
    'Runtime' : ['max', 'min']
})
# Out:
#           IMDB_Rating No_of_Votes Metascore Runtime
#                  mean         sum       min     max  min
# Genre
# Action       7.949419    72282412      33.0     321   45
# Adventure    7.937500    22576163      41.0     228   88
# Animation    7.930488    21978630      61.0     137   71
# Biography    7.938636    24006844      48.0     209   93
# Comedy       7.901290    27620327      45.0     188   68
# Crime        8.016822    33533615      47.0     229   80
# Drama        7.957439    61367304      28.0     242   64
# Family       7.800000      551221      67.0     115  100
# Fantasy      8.000000      146222       NaN      94   76
# Film-Noir    7.966667      367215      94.0     108  100
# Horror       7.909091     3742556      46.0     122   71
# Mystery      7.975000     4203004      52.0     138   96
# Thriller     7.800000       27733      81.0     108  108
# Western      8.350000     1289665      69.0     165  132

# %%
# loops in groups
for genre, df in genres:
    print(type(genre), type(df), end=" ")
    print(genre)
# Out:
# <class 'str'> <class 'pandas.DataFrame'> Action
# <class 'str'> <class 'pandas.DataFrame'> Adventure
# <class 'str'> <class 'pandas.DataFrame'> Animation
# <class 'str'> <class 'pandas.DataFrame'> Biography
# <class 'str'> <class 'pandas.DataFrame'> Comedy
# <class 'str'> <class 'pandas.DataFrame'> Crime
# <class 'str'> <class 'pandas.DataFrame'> Drama
# <class 'str'> <class 'pandas.DataFrame'> Family
# <class 'str'> <class 'pandas.DataFrame'> Fantasy
# <class 'str'> <class 'pandas.DataFrame'> Film-Noir
# <class 'str'> <class 'pandas.DataFrame'> Horror
# <class 'str'> <class 'pandas.DataFrame'> Mystery
# <class 'str'> <class 'pandas.DataFrame'> Thriller
# <class 'str'> <class 'pandas.DataFrame'> Western

# %%
# find number of movies staring with letter A, using apply fnction
def starting_with_A(group):
    return group['Series_Title'].str.startswith('A').sum()

# %%
genres.apply(starting_with_A)
# Out:
# Genre
# Action       10
# Adventure     2
# Animation     2
# Biography     9
# Comedy       14
# Crime         4
# Drama        21
# Family        0
# Fantasy       0
# Film-Noir     0
# Horror        1
# Mystery       0
# Thriller      0
# Western       0
# dtype: int64

# %%
# movies rank on each group
def rank_movies_genre(group):
    group['Rank_on_Genre'] = group['IMDB_Rating'].rank(ascending=False)
    return group

# %%
genres.apply(rank_movies_genre)
# Out:
#                                                    Series_Title Released_Year  \
# Genre
# Action   2                                      The Dark Knight          2008
#          5        The Lord of the Rings: The Return of the King          2003
#          8                                            Inception          2010
#          10   The Lord of the Rings: The Fellowship of the Ring          2001
#          13               The Lord of the Rings: The Two Towers          2002
# ...                                                         ...           ...
# Thriller 700                                    Wait Until Dark          1967
# Western  12                     Il buono, il brutto, il cattivo          1966
#          48                        Once Upon a Time in the West          1968
#          115                         Per qualche dollaro in più          1965
#          691                             The Outlaw Josey Wales          1976
#
# ...

# %%
# groupby on multiple columns
duo = imdb_movies.groupby(['Director','Star1'])

# %%
duo.size().sort_values(ascending=False).head(10)
# Out:
# Director           Star1
# Akira Kurosawa     Toshirô Mifune     7
# Joel Coen          Ethan Coen         6
# Charles Chaplin    Charles Chaplin    6
# Martin Scorsese    Robert De Niro     6
# John Huston        Humphrey Bogart    4
# Anthony Russo      Joe Russo          4
# Christopher Nolan  Christian Bale     4
# Clint Eastwood     Clint Eastwood     4
# Richard Linklater  Ethan Hawke        4
# Woody Allen        Woody Allen        4
# dtype: int64

# %%
duo.get_group(('Peter Jackson', 'Elijah Wood'))
# Out:
#                                          Series_Title Released_Year  Runtime  \
# 5       The Lord of the Rings: The Return of the King          2003      201
# 10  The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13              The Lord of the Rings: The Two Towers          2002      179
#
#      Genre  IMDB_Rating       Director        Star1  No_of_Votes        Gross  \
# 5   Action          8.9  Peter Jackson  Elijah Wood      1642758  377845905.0
# 10  Action          8.8  Peter Jackson  Elijah Wood      1661481  315544750.0
# 13  Action          8.7  Peter Jackson  Elijah Wood      1485555  342551365.0
#
#     Metascore
# 5        94.0
# 10       92.0
# 13       87.0

# %%
# most earning duo
duo['Gross'].sum().sort_values(ascending=False).head(1)
# Out:
# Director        Star1
# Akira Kurosawa  Toshirô Mifune    2.999877e+09
# Name: Gross, dtype: float64

# %%
ipl = pd.read_csv('./Datasets/deliveries.csv')
ipl.shape
# Out:
# (179078, 21)

# %%
ipl.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  str
#  3   bowling_team      179078 non-null  str
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  str
#  7   non_striker       179078 non-null  str
#  8   bowler            179078 non-null  str
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
# find top 10 batsman in terms of run
ipl.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(10)
# Out:
# batsman
# V Kohli           5434
# SK Raina          5415
# RG Sharma         4914
# DA Warner         4741
# S Dhawan          4632
# CH Gayle          4560
# MS Dhoni          4477
# RV Uthappa        4446
# AB de Villiers    4428
# G Gambhir         4223
# Name: batsman_runs, dtype: int64

# %%
# find the batsman with most no. of sixes
ipl[ipl['batsman_runs'] == 6].groupby('batsman').size().sort_values(ascending=False).head(1)
# Out:
# batsman
# CH Gayle    327
# dtype: int64

# %%
# v kohli runs against all team
ipl[ipl['batsman'] == 'V Kohli'].groupby('bowling_team')['batsman_runs'].sum()
# Out:
# bowling_team
# Chennai Super Kings        749
# Deccan Chargers            306
# Delhi Capitals              66
# Delhi Daredevils           763
# Gujarat Lions              283
# Kings XI Punjab            636
# Kochi Tuskers Kerala        50
# Kolkata Knight Riders      675
# Mumbai Indians             628
# Pune Warriors              128
# Rajasthan Royals           370
# Rising Pune Supergiant      83
# Rising Pune Supergiants    188
# Sunrisers Hyderabad        509
# Name: batsman_runs, dtype: int64

# %% [markdown]
# ## Mergin-Joining-Concatenating

# %%
courses = pd.read_csv('./Datasets/courses.csv')
students = pd.read_csv('./Datasets/students.csv')
nov = pd.read_csv('./Datasets/reg-month1.csv')
dec = pd.read_csv('./Datasets/reg-month2.csv')
matches = pd.read_csv('./Datasets/ipl-matches.csv')
delivaries = pd.read_csv('./Datasets/deliveries.csv')

# %%
nov.head()
# Out:
#    student_id  course_id
# 0          23          1
# 1          15          5
# 2          18          6
# 3          23          4
# 4          16          9

# %%
dec.head()
# Out:
#    student_id  course_id
# 0           3          5
# 1          16          7
# 2          12         10
# 3          12          1
# 4          14          9

# %%
# pd.concatenate
multi = pd.concat([nov, dec], keys=['nov', 'dec']) # multi index df

# %%
multi.loc[('nov', 8)]
# Out:
# student_id    22
# course_id      3
# Name: (nov, 8), dtype: int64

# %%
pd.concat([nov, dec], axis=1) # horizontally
# Out:
#     student_id  course_id  student_id  course_id
# 0         23.0        1.0           3          5
# 1         15.0        5.0          16          7
# 2         18.0        6.0          12         10
# 3         23.0        4.0          12          1
# 4         16.0        9.0          14          9
# 5         18.0        1.0           7          7
# 6          1.0        1.0           7          2
# 7          7.0        8.0          16          3
# 8         22.0        3.0          17         10
# 9         15.0        1.0          11          8
# 10        19.0        4.0          14          6
# 11         1.0        6.0          12          5
# 12         7.0       10.0          12          7
# 13        11.0        7.0          18          8
# 14        13.0        3.0           1         10
# 15        24.0        4.0           1          9
# 16        21.0        1.0           2          5
# 17        16.0        5.0           7          6
# ...

# %% [markdown]
# <img src="https://learnsql.com/blog/learn-and-practice-sql-joins/2.png" height="500" width="500">

# %%
# merging
# inner join
reg = pd.concat([nov, dec], ignore_index=True)
students.merge(reg, how='inner', on='student_id') # only common
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23          1
# 1            1       Kailash Harjo       23          6
# 2            1       Kailash Harjo       23         10
# 3            1       Kailash Harjo       23          9
# 4            2         Esha Butala        1          5
# 5            3      Parveen Bhalla        3          3
# 6            3      Parveen Bhalla        3          5
# 7            7        Tarun Thaker        9          8
# 8            7        Tarun Thaker        9         10
# 9            7        Tarun Thaker        9          7
# 10           7        Tarun Thaker        9          2
# 11           7        Tarun Thaker        9          6
# 12          11  David Mukhopadhyay       20          7
# 13          11  David Mukhopadhyay       20          8
# 14          11  David Mukhopadhyay       20         10
# 15          12          Radha Dutt       19         10
# ...

# %%
# left join
courses.merge(reg, how='left', on='course_id')
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499        23.0
# 1           1            python   2499        18.0
# 2           1            python   2499         1.0
# 3           1            python   2499        15.0
# 4           1            python   2499        21.0
# 5           1            python   2499        25.0
# 6           1            python   2499        12.0
# 7           1            python   2499        14.0
# 8           1            python   2499        38.0
# 9           2               sql   3499        19.0
# 10          2               sql   3499         7.0
# 11          3     data analysis   4999        22.0
# 12          3     data analysis   4999        13.0
# 13          3     data analysis   4999        23.0
# 14          3     data analysis   4999         3.0
# 15          3     data analysis   4999        16.0
# 16          4  machine learning   9999        23.0
# ...

# %%
#right join
students.merge(reg, how='right', on='student_id')
# Out:
#     student_id                name  partner  course_id
# 0           23      Chhavi Lachman     18.0          1
# 1           15           Preet Sha     16.0          5
# 2           18     Fardeen Mahabir     13.0          6
# 3           23      Chhavi Lachman     18.0          4
# 4           16        Elias Dodiya     25.0          9
# 5           18     Fardeen Mahabir     13.0          1
# 6            1       Kailash Harjo     23.0          1
# 7            7        Tarun Thaker      9.0          8
# 8           22          Yash Sethi     21.0          3
# 9           15           Preet Sha     16.0          1
# 10          19        Qabeel Raman     12.0          4
# 11           1       Kailash Harjo     23.0          6
# 12           7        Tarun Thaker      9.0         10
# 13          11  David Mukhopadhyay     20.0          7
# 14          13      Munni Varghese     24.0          3
# 15          24        Radhika Suri     17.0          4
# ...

# %%
# outer join or full join
students.merge(reg, how='outer', on='student_id')
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo     23.0        1.0
# 1            1       Kailash Harjo     23.0        6.0
# 2            1       Kailash Harjo     23.0       10.0
# 3            1       Kailash Harjo     23.0        9.0
# 4            2         Esha Butala      1.0        5.0
# 5            3      Parveen Bhalla      3.0        3.0
# 6            3      Parveen Bhalla      3.0        5.0
# 7            4         Marlo Dugal     14.0        NaN
# 8            5         Kusum Bahri      6.0        NaN
# 9            6  Lakshmi Contractor     10.0        NaN
# 10           7        Tarun Thaker      9.0        8.0
# 11           7        Tarun Thaker      9.0       10.0
# 12           7        Tarun Thaker      9.0        7.0
# 13           7        Tarun Thaker      9.0        2.0
# 14           7        Tarun Thaker      9.0        6.0
# 15           8      Radheshyam Dey      5.0        NaN
# ...

# %%
# total revenue
revenue = reg.merge(courses, how='inner', on='course_id')['price'].sum()
print(revenue)
# Out:
# 154247

# %%
# month by month revenue
months_of_nov_dec = pd.concat([nov, dec], keys=['Nov', 'Dec']).reset_index()
months_of_nov_dec.merge(courses, how='inner', on='course_id').groupby('level_0')['price'].sum()
# Out:
# level_0
# Dec    65072
# Nov    89175
# Name: price, dtype: int64

# %%
# print registration table -> student - course - price
students.merge(reg, how='inner', on='student_id').merge(courses, how='inner', on='course_id')[['name', 'course_name', 'price']]
# Out:
#                   name       course_name  price
# 0        Kailash Harjo            python   2499
# 1        Kailash Harjo          power bi   1899
# 2        Kailash Harjo           pyspark   2499
# 3        Kailash Harjo            plotly    699
# 4          Esha Butala           tableau   2499
# 5       Parveen Bhalla     data analysis   4999
# 6       Parveen Bhalla           tableau   2499
# 7         Tarun Thaker            pandas   1099
# 8         Tarun Thaker           pyspark   2499
# 9         Tarun Thaker          ms sxcel   1599
# 10        Tarun Thaker               sql   3499
# 11        Tarun Thaker          power bi   1899
# 12  David Mukhopadhyay          ms sxcel   1599
# 13  David Mukhopadhyay            pandas   1099
# 14  David Mukhopadhyay           pyspark   2499
# 15          Radha Dutt           pyspark   2499
# 16          Radha Dutt            python   2499
# 17          Radha Dutt           tableau   2499
# 18          Radha Dutt          ms sxcel   1599
# ...

# %%
# barchart for revenue/courses
reg.merge(courses, how='inner', on='course_id').groupby('course_name')['price'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='course_name'>

# %%
# find students who enrolled both months
common_student_id = np.intersect1d(nov['student_id'], dec['student_id'])

# %%
students[students['student_id'].isin(common_student_id)]['name']
# Out:
# 0          Kailash Harjo
# 2         Parveen Bhalla
# 6           Tarun Thaker
# 10    David Mukhopadhyay
# 15          Elias Dodiya
# 16          Yasmin Palan
# 17       Fardeen Mahabir
# 21            Yash Sethi
# 22        Chhavi Lachman
# Name: name, dtype: str

# %%
# courses with 0 enrollments
zero_enroll_courses = np.setdiff1d(courses['course_id'], reg['course_id'])
courses[courses['course_id'].isin(zero_enroll_courses)]
# Out:
#     course_id course_name  price
# 10         11       Numpy    699
# 11         12         C++   1299

# %%
# student name - partner name
# self join
students.merge(students, how='inner', left_on='partner', right_on='student_id')[['name_x', 'name_y']]
# Out:
#                 name_x              name_y
# 0        Kailash Harjo      Chhavi Lachman
# 1          Esha Butala       Kailash Harjo
# 2       Parveen Bhalla      Parveen Bhalla
# 3          Marlo Dugal    Pranab Natarajan
# 4          Kusum Bahri  Lakshmi Contractor
# 5   Lakshmi Contractor      Aayushman Sant
# 6         Tarun Thaker   Nitika Chatterjee
# 7       Radheshyam Dey         Kusum Bahri
# 8    Nitika Chatterjee         Marlo Dugal
# 9       Aayushman Sant      Radheshyam Dey
# 10  David Mukhopadhyay       Hanuman Hegde
# 11          Radha Dutt        Qabeel Raman
# 12      Munni Varghese        Radhika Suri
# 13    Pranab Natarajan          Yash Sethi
# 14           Preet Sha        Elias Dodiya
# 15        Elias Dodiya     Shashank D’Alia
# 16        Yasmin Palan        Tarun Thaker
# 17     Fardeen Mahabir      Munni Varghese
# 18        Qabeel Raman          Radha Dutt
# 19       Hanuman Hegde  David Mukhopadhyay
# 20          Seema Kota           Preet Sha
# ...

# %%
# top 3 students with most enrollments
students.merge(reg, how='inner', on='student_id').groupby(['student_id', 'name'])['name'].value_counts().sort_values(ascending=False).head(3)
# Out:
# student_id  name
# 23          Chhavi Lachman      6
# 7           Tarun Thaker        5
# 14          Pranab Natarajan    4
# Name: count, dtype: int64

# %% [markdown]
# ## Multi-Index Series & DF

# %%
# multi indexing series (hierarchial indexing)
multiindex = pd.MultiIndex.from_product([['cse', 'ai'], [2023, 2024, 2025, 2026]])
# using tuple
# index_val = [('cse', 2023), ('cse', 2024), ('cse', 2025), ('ai', 2024), ('ai', 2025), ('ai', 2023), ('cse', 2026),('ai', 2026)]
# multiindex = pd.MultiIndex.from_tuples(index_val)
s = pd.Series([1, 2, 1, 3, 1, 2, 2, 3], index=multiindex)
s
# Out:
# cse  2023    1
#      2024    2
#      2025    1
#      2026    3
# ai   2023    1
#      2024    2
#      2025    2
#      2026    3
# dtype: int64

# %%
s['cse']
# Out:
# 2023    1
# 2024    2
# 2025    1
# 2026    3
# dtype: int64

# %%
s[('cse', 2024)]
# Out:
# np.int64(2)

# %%
t = s.unstack()

# %%
t.stack()
# Out:
# ai   2023    1
#      2024    2
#      2025    2
#      2026    3
# cse  2023    1
#      2024    2
#      2025    1
#      2026    3
# dtype: int64

# %%
# Multi Index DataFrame
branch_df1 = pd.DataFrame([
    [1, 3, 2, 3],
    [2, 2, 4, 2],
    [7, 2, 0, 0],
    [10, 1, 1, 9],
    [3, 8, 2, 8],
    [4, 4, 3, 7],
    [8, 3, 8, 1],
    [3, 4, 10, 2]
], index=multiindex,
columns=pd.MultiIndex.from_product([['kolkata', 'bardhaman'], ['avg_package', 'students']]))
branch_df1
# Out:
#              kolkata            bardhaman
#          avg_package students avg_package students
# cse 2023           1        3           2        3
#     2024           2        2           4        2
#     2025           7        2           0        0
#     2026          10        1           1        9
# ai  2023           3        8           2        8
#     2024           4        4           3        7
#     2025           8        3           8        1
#     2026           3        4          10        2

# %%
branch_df1.unstack().stack().stack()
# Out:
#                       kolkata  bardhaman
# ai  2023 avg_package        3          2
#          students           8          8
#     2024 avg_package        4          3
#          students           4          7
#     2025 avg_package        8          8
#          students           3          1
#     2026 avg_package        3         10
#          students           4          2
# cse 2023 avg_package        1          2
#          students           3          3
#     2024 avg_package        2          4
#          students           2          2
#     2025 avg_package        7          0
#          students           2          0
#     2026 avg_package       10          1
#          students           1          9

# %%
branch_df1.shape
# Out:
# (8, 4)

# %%
branch_df1.head()
# Out:
#              kolkata            bardhaman
#          avg_package students avg_package students
# cse 2023           1        3           2        3
#     2024           2        2           4        2
#     2025           7        2           0        0
#     2026          10        1           1        9
# ai  2023           3        8           2        8

# %%
branch_df1.info()
# Out:
# <class 'pandas.DataFrame'>
# MultiIndex: 8 entries, ('cse', np.int64(2023)) to ('ai', np.int64(2026))
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   (kolkata, avg_package)    8 non-null      int64
#  1   (kolkata, students)       8 non-null      int64
#  2   (bardhaman, avg_package)  8 non-null      int64
#  3   (bardhaman, students)     8 non-null      int64
# dtypes: int64(4)
# memory usage: 820.0+ bytes

# %%
branch_df1.describe()
# Out:
#           kolkata            bardhaman
#       avg_package students avg_package  students
# count     8.00000  8.00000    8.000000  8.000000
# mean      4.75000  3.37500    3.750000  4.000000
# std       3.19598  2.13391    3.494894  3.464102
# min       1.00000  1.00000    0.000000  0.000000
# 25%       2.75000  2.00000    1.750000  1.750000
# 50%       3.50000  3.00000    2.500000  2.500000
# 75%       7.25000  4.00000    5.000000  7.250000
# max      10.00000  8.00000   10.000000  9.000000

# %%
branch_df1.duplicated()
# Out:
# cse  2023    False
#      2024    False
#      2025    False
#      2026    False
# ai   2023    False
#      2024    False
#      2025    False
#      2026    False
# dtype: bool

# %%
# slicing
branch_df1 = branch_df1.sort_index()
branch_df1.loc[('ai', 2024):('cse', 2025)]
# Out:
#              kolkata            bardhaman
#          avg_package students avg_package students
# ai  2024           4        4           3        7
#     2025           8        3           8        1
#     2026           3        4          10        2
# cse 2023           1        3           2        3
#     2024           2        2           4        2
#     2025           7        2           0        0

# %%
branch_df1.iloc[1:7]
# Out:
#              kolkata            bardhaman
#          avg_package students avg_package students
# ai  2024           4        4           3        7
#     2025           8        3           8        1
#     2026           3        4          10        2
# cse 2023           1        3           2        3
#     2024           2        2           4        2
#     2025           7        2           0        0

# %%
branch_df1.iloc[[4, 2, 3]]
# Out:
#              kolkata            bardhaman
#          avg_package students avg_package students
# cse 2023           1        3           2        3
# ai  2025           8        3           8        1
#     2026           3        4          10        2

# %%
branch_df1.iloc[:, 1:3]
# Out:
#           kolkata   bardhaman
#          students avg_package
# ai  2023        8           2
#     2024        4           3
#     2025        3           8
#     2026        4          10
# cse 2023        3           2
#     2024        2           4
#     2025        2           0
#     2026        1           1

# %%
branch_df1.sort_index(ascending=[False, True])
# Out:
#              kolkata            bardhaman
#          avg_package students avg_package students
# cse 2023           1        3           2        3
#     2024           2        2           4        2
#     2025           7        2           0        0
#     2026          10        1           1        9
# ai  2023           3        8           2        8
#     2024           4        4           3        7
#     2025           8        3           8        1
#     2026           3        4          10        2

# %%
branch_df1.sort_index(level=1, ascending=False)
# Out:
#              kolkata            bardhaman
#          avg_package students avg_package students
# cse 2026          10        1           1        9
# ai  2026           3        4          10        2
# cse 2025           7        2           0        0
# ai  2025           8        3           8        1
# cse 2024           2        2           4        2
# ai  2024           4        4           3        7
# cse 2023           1        3           2        3
# ai  2023           3        8           2        8

# %%
branch_df1.transpose()
# Out:
#                         ai                 cse
#                       2023 2024 2025 2026 2023 2024 2025 2026
# kolkata   avg_package    3    4    8    3    1    2    7   10
#           students       8    4    3    4    3    2    2    1
# bardhaman avg_package    2    3    8   10    2    4    0    1
#           students       8    7    1    2    3    2    0    9

# %%
branch_df1.swaplevel(axis=1)
# Out:
#          avg_package students avg_package  students
#              kolkata  kolkata   bardhaman bardhaman
# ai  2023           3        8           2         8
#     2024           4        4           3         7
#     2025           8        3           8         1
#     2026           3        4          10         2
# cse 2023           1        3           2         3
#     2024           2        2           4         2
#     2025           7        2           0         0
#     2026          10        1           1         9

# %% [markdown]
# ## Melt and Pivot

# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTtUqMxB71EW9jHHUPzGZx_f2Vqotz4y7_LvQ&s' height=500 width=500>

# %%
# melt -> wide to long data
student = pd.DataFrame([
    [120, 60],
    [222, 100]],
columns=['cse', 'ai']
)
student.melt(var_name='branch', value_name='students')
# Out:
#   branch  students
# 0    cse       120
# 1    cse       222
# 2     ai        60
# 3     ai       100

# %%
student
# Out:
#    cse   ai
# 0  120   60
# 1  222  100

# %%
student = pd.DataFrame({
    'branch' : ['cse', 'ai', 'ece', 'ee'],
    '2023' : [30, 30, 50, 50],
    '2024' : [35, 35, 60, 60],
    '2025' : [40, 40, 70, 70]
})
student
# Out:
#   branch  2023  2024  2025
# 0    cse    30    35    40
# 1     ai    30    35    40
# 2    ece    50    60    70
# 3     ee    50    60    70

# %%
student.melt(id_vars=['branch'])
# Out:
#    branch variable  value
# 0     cse     2023     30
# 1      ai     2023     30
# 2     ece     2023     50
# 3      ee     2023     50
# 4     cse     2024     35
# 5      ai     2024     35
# 6     ece     2024     60
# 7      ee     2024     60
# 8     cse     2025     40
# 9      ai     2025     40
# 10    ece     2025     70
# 11     ee     2025     70
